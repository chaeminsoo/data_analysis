# %%
# Developer Recruitment in programmers

# %%
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse

# %%
baseUrl = ''
plusUrl = input()
input_page = input("How many pages do you want to crawl: ")
pageNum = 1
url = f'https://programmers.co.kr/job?min_salary=&min_career=&min_employees=&order=recent&page={pageNum}'
# print(plusUrl)
# print(input_page)
# print(url)
# Out:
# 1
# 1
# https://programmers.co.kr/job?min_salary=&min_career=&min_employees=&order=recent&page=1

# %%
while pageNum <= input_page:
