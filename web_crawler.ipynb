# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
source_url = 'https://search.musinsa.com/ranking/best'

# %%
# start crawling based on site's HTML structure
req = requests.get(source_url)
html = req.content # original text
soup = BeautifulSoup(html, 'lxml') # (target, method(lxml)) 
content_table = soup.find(name='table', attrs={'class':'table-hover'})
